# %%
import google.generativeai as genai
import requests
from bs4 import BeautifulSoup
import subprocess
import os
import filecmp
from glob import glob
from pathlib import Path
import pandas as pd
import sys
import subprocess

# %%
# Configure the Gemini client with your API key
genai.configure(api_key="")
model = genai.GenerativeModel("gemini-1.5-flash")

def fetch_jira_bug_report(jira_url):
    """
    Fetch and parse a bug report from an Apache Jira link, including the priority.
    :param jira_url: URL to the Jira issue.
    :return: Bug report details including priority as a string.
    """
    try:
        response = requests.get(jira_url)
        if response.status_code != 200:
            raise Exception(f"Failed to fetch Jira URL. HTTP Status Code: {response.status_code}")
        
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract bug report title
        title_element = soup.find("h1")
        title = title_element.text.strip() if title_element else "No title available."

        # Extract description
        description_element = soup.find("div", {"id": "descriptionmodule"})
        description = description_element.text.strip() if description_element else "No description available."

        # Extract priority
        priority_element = soup.find("span", {"id": "priority-val"})
        priority = priority_element.text.strip() if priority_element else "No priority available."

        # Combine title, description, and priority
        bug_report = (
            f"Title: {title}\n\n"
            f"Description: {description}\n\n"
            f"Priority: {priority}"
        )
        return bug_report
    except Exception as e:
        print(f"Error fetching Jira bug report: {e}")
        return ""


def compare_folders(folder1: str, folder2: str):
    """
    Compares the files in two folders. Reports files that are unique to each folder,
    files that differ in content, and the content differences for differing files.

    Args:
        folder1 (str): Path to the first folder.
        folder2 (str): Path to the second folder.

    Returns:
        dict: A dictionary with comparison results.
    """
    if not os.path.isdir(folder1) or not os.path.isdir(folder2):
        raise ValueError("Both inputs must be valid folder paths.")

    # Get list of files with .java extension in each folder
    print(f"Comparing files in {folder1} and {folder2}")
    files1 = glob(f'{folder1}/**/*.java', recursive=True)
    files2 = glob(f'{folder2}/**/*.java', recursive=True)

    print(f"Found {len(files1)} files in {folder1}")
    for file in files1:
        print(f"  {file}")
    print(f"Found {len(files2)} files in {folder2}")
    for file in files2:
        print(f"  {file}")
        

    # find files relative to the folder
    files1 = [os.path.relpath(file, folder1) for file in files1]
    files2 = [os.path.relpath(file, folder2) for file in files2]

    # Find files unique to each folder
    unique_files1 = set(files1) - set(files2)
    unique_files2 = set(files2) - set(files1)

    # Find files that are common to both folders
    common_files = set(files1) & set(files2)

    print(f"Files unique to {folder1}:")
    for file in unique_files1:
        print(f"  {file}")

    print(f"Files unique to {folder2}:")
    for file in unique_files2:
        print(f"  {file}")

    # for each common file, compare the content
    differing_files = []
    for file in common_files:
        file1 = os.path.join(folder1, file)
        file2 = os.path.join(folder2, file)
        if not filecmp.cmp(file1, file2):
            differing_files.append(file)

    print(f"Files differing in content:")
    for file in differing_files:
        print(f"  {file}")


    return {
        "unique_files1": unique_files1,
        "unique_files2": unique_files2,
        "differing_files": differing_files
    }

# %%
active_bugs_df = pd.read_csv("active-bugs.csv")
active_bugs_df
# Out:
#     bug.id                         revision.id.buggy  \
# 0        1  8f46f467a33ace44ccd9f394910940b6c48a3827
# 1        2  b0e1b80b6d4a10a9c9f46539bc4c7a3cce55886e
# 2        3  85248e8ae52232ed75c2b4c52d4071bdf192db37
# 3        4  8ca630b76ebcfe24915a9edb3a6de756cab761c9
# 4        5  2b0a94aee899d9e7d855c402ad40eb4e318f46e7
# 5        7  73276486b1f39510bf27cb6c0684da805b121f5d
# 6        8  6a6bb48840aa0043200a5d9f6fffea47aea1a8db
# 7        9  298804b71d4e5f8b621f48a300f421229a3f5c86
# 8       10  d0f6128191443bbf49e1c9fde616f87c16486db4
# 9       11  33abc034037e3ef5d85d1b03010122617c386827
# 10      12  b8f825936796e2f5b6663de021aefa53fa728f67
# 11      13  e2ba946ea0e01c36c84f97f483e1d22cfd64b917
# 12      14  b7b2069f9d846c6aea5fee98508ec1491fdf1123
# 13      15  c338c8aca40d43efda580057f6d41ba228e26ec1
# 14      16  eed25612b11caf1f4e6e572e58db4306f31803c9
# 15      17  cfbb46adb163d9b8af00e9a29e6b42d597f8804f
# 16      18  9c5ce3501938cff01d78b7a1fff10a60abe9e0cf
# 17      19  c8606251c904dfaf5303f71b788e12f7fff15fab
# 18      20  b1331806960001da95424315b6103d755107b519
# 19      21  028893dad71e4823f67a427903699999d6eedd4b
# 20      22  ae2ff1d12efd8f0f55bfa1febd8c77af4bb433c7
# 21      23  88cf9e4ab6e1b127de46fb2540f4d1fffac56442
# 22      24  ac6e754ecfc86822aa1ab74d657b0b3f0222b2e6
# 23      25  02dd7c20646bf67dcfb6f7da6beeb7cdffc6ac22
# 24      26  879c762baac4a9d7aade43d302e730e239a54c21
# 25      27  6a999186695d404ccb6c1528df68fe2eb42863c2
# 26      28  10b14afb9ff42a3f216296f526f65d001b545e3f
# 27      29  a2cf820dd69e55050a8db004c305a6133c3feb2e
# 28      30  5560a086886c4d6dba2c30eb75e57e3167765c6e
# 29      31  4381ba54c845402f18760fb04ff1f6db1922f6b2
# 30      32  23df383408513eddaf3e6dc4244c89fd48427695
# 31      33  99222749ca9b0d9338ed5df796db9c32b82424b8
# 32      34  40c4892e932afba6ac2ace430ee59a465565bd50
# 33      35  a154084dbf5af77f6f3a64a7561fd77aadb78429
# 34      36  f6af62367494ff8d0d7844f7f435e5ee36c81dcf
# 35      37  9e51962309fac2806f5fe0e4e3df94e0e187607a
# 36      38  5764b6270287a74d31cb83f70ab38bdd916e619e
# 37      39  70a392756c713f404fed0e3ddd48aa18ce20485f
# 38      40  e400f9256a2af526e9a06b9d5d2965965109a8db
#
#                            revision.id.fixed report.id  \
# 0   b0e1b80b6d4a10a9c9f46539bc4c7a3cce55886e    CLI-13
# 1   2ff9573ffb08dd52ec3a55a49f2d77a1e94efbdf    CLI-51
# 2   d35f2fa7a06457469a617677eeb4c1dc21484006     cli-1
# 3   f78959477b207bf710049aa35730ef7659f0a1b9     cli-1
# 4   3880640ee6268a2ecb2912e1ae896153dc2229e5   CLI-133
# 5   4ee0d6c4f1b553858aeabf3ee6fb37d764f263e2   CLI-121
# 6   4f407378c93b9e2a8e24c855e8bed5eb12bf7a06   CLI-151
# 7   fea35870b69c0d37ab36ab6783edbc7aacc0842c   CLI-149
# 8   d72a578a8949e4b1c437ec55997d8786836f139c   CLI-156
# 9   d36adebd3547279b709960c902c3fb7b89a9a4ef     cli-1
# 10  aa050a69b2395f496f953f4f9c4f63a475dcf430     cli-1
# 11  538fb6889f0387a40b821cfb315685e929110736    CLI-61
# 12  c338c8aca40d43efda580057f6d41ba228e26ec1   CLI-144
# 13  a93139165b160af1c908c85a06b0af6b3dda3387   CLI-158
# 14  f104dd060c6c88450ac9ee9eb818b26374512440   CLI-123
# 15  9c5ce3501938cff01d78b7a1fff10a60abe9e0cf   CLI-163
# 16  c8606251c904dfaf5303f71b788e12f7fff15fab   CLI-164
# 17  b1331806960001da95424315b6103d755107b519   CLI-164
# 18  99aa05af2bfef3980ad8f94230cd077e8d30c5ea   CLI-165
# 19  9cd78b4c83df53ba302baadac4c976ca84f428f9   CLI-150
# 20  db4a638cf642fd7d031fcaebffa306b0a16ba771     cli-1
# 21  2ddaae14dd23643a4b5f71f8274534b0b34556a4   CLI-162
# 22  02dd7c20646bf67dcfb6f7da6beeb7cdffc6ac22   CLI-162
# 23  6a585453d385449dc23d90479488f92f02cd6b83   CLI-162
# 24  aa2434d301c49d100f50af544333886a6767ce9d   CLI-177
# 25  4c971f08861e8cefb8ca9ac20799bfdad4e973a4   CLI-182
# 26  3433f467554985a6bd9bf530a4810376be6fe250   CLI-201
# 27  20002f7f4e971349a1c95dd3b05846c5b824b65c   CLI-185
# 28  324b7f901b91614927926a5bab1d9e0e2325f018   CLI-203
# 29  4d2c8a22d1e1831858029b8ef225a07f4445a221   CLI-205
# 30  777cb81088d47472df21a452edd5ba568d4b3fdf   CLI-193
# 31  483f811dfefdc6bee162481425f261d983f15e4a   CLI-207
# 32  62a3b36efc78e53c233c2fb49cc8199c5eabec1d   CLI-215
# 33  085a1538fa20d8e48faad49eaffd697f024bf1af   CLI-252
# 34  afc13c445a4c80432e52d735685b272fadfeeddf   CLI-266
# 35  1bf9e6c551b6a2e7d37291673a1ff77c338ce131   CLI-265
# 36  ac2a1c85616f0140418de9190389fe7b80296c39   CLI-265
# 37  0b453953fa5f55cf2e8fd034d4d55972deb7647a   CLI-274
# 38  b0024d482050a08efc36c3cabee37c0af0e57a10   CLI-282
#
#                                        report.url
# 0    https://issues.apache.org/jira/browse/CLI-13
# 1    https://issues.apache.org/jira/browse/CLI-51
# 2     https://issues.apache.org/jira/browse/CLI-1
# 3     https://issues.apache.org/jira/browse/CLI-1
# 4   https://issues.apache.org/jira/browse/CLI-133
# 5   https://issues.apache.org/jira/browse/CLI-121
# 6   https://issues.apache.org/jira/browse/CLI-151
# 7   https://issues.apache.org/jira/browse/CLI-149
# 8   https://issues.apache.org/jira/browse/CLI-156
# 9     https://issues.apache.org/jira/browse/CLI-1
# 10    https://issues.apache.org/jira/browse/CLI-1
# 11   https://issues.apache.org/jira/browse/CLI-61
# 12  https://issues.apache.org/jira/browse/CLI-144
# 13  https://issues.apache.org/jira/browse/CLI-158
# 14  https://issues.apache.org/jira/browse/CLI-123
# 15  https://issues.apache.org/jira/browse/CLI-163
# 16  https://issues.apache.org/jira/browse/CLI-164
# 17  https://issues.apache.org/jira/browse/CLI-164
# 18  https://issues.apache.org/jira/browse/CLI-165
# 19  https://issues.apache.org/jira/browse/CLI-150
# 20    https://issues.apache.org/jira/browse/CLI-1
# 21  https://issues.apache.org/jira/browse/CLI-162
# 22  https://issues.apache.org/jira/browse/CLI-162
# 23  https://issues.apache.org/jira/browse/CLI-162
# 24  https://issues.apache.org/jira/browse/CLI-177
# 25  https://issues.apache.org/jira/browse/CLI-182
# 26  https://issues.apache.org/jira/browse/CLI-201
# 27  https://issues.apache.org/jira/browse/CLI-185
# 28  https://issues.apache.org/jira/browse/CLI-203
# 29  https://issues.apache.org/jira/browse/CLI-205
# 30  https://issues.apache.org/jira/browse/CLI-193
# 31  https://issues.apache.org/jira/browse/CLI-207
# 32  https://issues.apache.org/jira/browse/CLI-215
# 33  https://issues.apache.org/jira/browse/CLI-252
# 34  https://issues.apache.org/jira/browse/CLI-266
# 35  https://issues.apache.org/jira/browse/CLI-265
# 36  https://issues.apache.org/jira/browse/CLI-265
# 37  https://issues.apache.org/jira/browse/CLI-274
# 38  https://issues.apache.org/jira/browse/CLI-282

# %%
def generated_test_case(buggy_project_folder, fixed_project_folder, bug_row, bug_id, output_folder):
    jira_url = bug_row['report.url']
    bug_report_parsed = fetch_jira_bug_report(jira_url)
    folder_comparison = compare_folders(buggy_project_folder, fixed_project_folder)

    buggy_code_paths = [Path(buggy_project_folder) / file for file in folder_comparison['differing_files']]
    fixed_code_paths = [Path(fixed_project_folder) / file for file in folder_comparison['differing_files']]

    buggy_code_text = ""
    for path in buggy_code_paths:
        buggy_code_text += f"Filename: {str(path)}\n\n"
        buggy_code_text += path.read_text()

    fixed_code_text = ""
    for path in fixed_code_paths:
        fixed_code_text += f"Filename: {str(path)}\n\n"
        fixed_code_text += path.read_text()

    prompt = f'''There is a bug fix in the java code, Bug report is as follows:
    {bug_report_parsed}
    Buggy Code:
    {buggy_code_text}
    Fixed Code:
    {fixed_code_text}
    Generate test cases that covers the bug. Do not include any text or explanation, provide only the test cases.
    All the test should be in a single method named generated_tests and class name should be CustomTest.
    Generated Test case should be executable both in the buggy and fixed code, and should cover the bug.
    '''

    try:
        response = model.generate_content(prompt)
        generated_test_case = response.text.strip()
        # delete first and last line
        generated_test_case = generated_test_case.split("\n")[1:-1]
        generated_test_case = "\n".join(generated_test_case)
        # write the generated test case to a file
        test_case_file = Path(output_folder) / f"CustomTest_{bug_id}.java"
        test_case_file.write_text(generated_test_case)
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
bug_id = 40
bug_source_folder = f'/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/OUTPUT_BUGGY/Cli/Cli_{bug_id}_buggy'
bug_fixed_folder = f'/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/OUTPUT_FIXED/Cli/Cli_{bug_id}_fixed'
buggy_output_folder = f'/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/generated_tests/OUTPUT_BUGGY/Cli/Cli_{bug_id}_buggy/src/test/java/org/apache/commons/cli'

related_bug_row = active_bugs_df.loc[active_bugs_df['bug.id'] == bug_id]
generated_test_case(bug_source_folder, bug_fixed_folder, related_bug_row, bug_id,buggy_output_folder, fixed_output_folder)

# %%
active_bugs = active_bugs_df.to_dict(orient='records')
generated_tests_folder = Path("/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/generated_tests")
for row in active_bugs:
    print("Processing bug:", row['bug.id'])
    bug_id = row['bug.id']
    report_url = row['report.url']
    bug_source_folder = f'/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_{bug_id}_buggy'
    bug_fixed_folder = f'/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_{bug_id}_fixed'

    # list all files in bug source folder recursively
    files = glob(f'{bug_source_folder}/**/*.java', recursive=True)
    # if there are no java files in the folder, skip the bug
    if len(files) == 0:
        print(f"No java files found in {bug_source_folder}. Skipping bug.")
        continue

    files = glob(f'{bug_fixed_folder}/**/*.java', recursive=True)
    # if there are no java files in the folder, skip the bug
    if len(files) == 0:
        print(f"No java files found in {bug_fixed_folder}. Skipping bug.")
        continue

    generated_test_case(bug_source_folder, bug_fixed_folder, row, bug_id, generated_tests_folder)
# Out:
# Processing bug: 1
# No java files found in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_1_fixed. Skipping bug.
# Processing bug: 2
# No java files found in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_2_fixed. Skipping bug.
# Processing bug: 3
# Comparing files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy and /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed
# Found 43 files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/CLI2ConverterTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/CLI2Converter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/CommandLineParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/UnrecognizedOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/OptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/ParseException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/Options.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/TypeHandler.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/GnuParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/Parser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/PosixParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/OptionGroup.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/OptionValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/MissingArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/MissingOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/Util.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/BasicParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/AlreadySelectedException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/java/org/apache/commons/cli/PatternOptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/OptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/ValueTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/HelpFormatterExamples.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/OptionGroupTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/LongOptionWithShort.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/BuildTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/PatternOptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/GnuParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/ArgumentIsOptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/OptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/TestHelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/ParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/ValuesTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/ParseRequiredTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/ApplicationTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/OptionsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/BugsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/bug/BugCLI71Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/bug/BugCLI18Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/bug/BugCLI51Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli/bug/BugCLI13Test.java
# Found 43 files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/CLI2ConverterTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/CLI2Converter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/CommandLineParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/UnrecognizedOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/OptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/ParseException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/Options.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/TypeHandler.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/GnuParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/Parser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/PosixParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/OptionGroup.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/OptionValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/MissingArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/MissingOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/Util.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/BasicParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/AlreadySelectedException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/java/org/apache/commons/cli/PatternOptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/OptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/ValueTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/HelpFormatterExamples.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/OptionGroupTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/LongOptionWithShort.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/BuildTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/PatternOptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/GnuParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/ArgumentIsOptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/OptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/TestHelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/ParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/ValuesTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/ParseRequiredTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/ApplicationTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/OptionsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/BugsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/bug/BugCLI71Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/bug/BugCLI18Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/bug/BugCLI51Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed/src/test/org/apache/commons/cli/bug/BugCLI13Test.java
# Files unique to /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy:
# Files unique to /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_3_fixed:
# Files differing in content:
#   src/java/org/apache/commons/cli/TypeHandler.java
# Processing bug: 4
# Comparing files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy and /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed
# Found 43 files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/CLI2ConverterTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/CLI2Converter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/CommandLineParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/UnrecognizedOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/OptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/ParseException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/Options.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/TypeHandler.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/GnuParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/Parser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/PosixParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/OptionGroup.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/OptionValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/MissingArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/MissingOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/Util.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/BasicParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/AlreadySelectedException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/java/org/apache/commons/cli/PatternOptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/OptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/ValueTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/HelpFormatterExamples.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/OptionGroupTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/LongOptionWithShort.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/BuildTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/PatternOptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/GnuParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/ArgumentIsOptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/OptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/TestHelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/ParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/ValuesTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/ParseRequiredTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/ApplicationTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/OptionsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/BugsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/bug/BugCLI71Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/bug/BugCLI18Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/bug/BugCLI51Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli/bug/BugCLI13Test.java
# Found 43 files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/CLI2ConverterTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/CLI2Converter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/CommandLineParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/UnrecognizedOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/OptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/ParseException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/Options.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/TypeHandler.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/GnuParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/Parser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/PosixParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/OptionGroup.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/OptionValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/MissingArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/MissingOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/Util.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/BasicParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/AlreadySelectedException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/java/org/apache/commons/cli/PatternOptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/OptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/ValueTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/HelpFormatterExamples.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/OptionGroupTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/LongOptionWithShort.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/BuildTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/PatternOptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/GnuParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/ArgumentIsOptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/OptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/TestHelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/ParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/ValuesTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/ParseRequiredTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/ApplicationTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/OptionsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/BugsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/bug/BugCLI71Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/bug/BugCLI18Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/bug/BugCLI51Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed/src/test/org/apache/commons/cli/bug/BugCLI13Test.java
# Files unique to /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy:
# Files unique to /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_4_fixed:
# Files differing in content:
#   src/java/org/apache/commons/cli/Parser.java
# Processing bug: 5
# Comparing files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy and /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed
# Found 45 files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/CLI2ConverterTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/CLI2Converter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/CommandLineParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/UnrecognizedOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/OptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/ParseException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/Options.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/TypeHandler.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/GnuParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/Parser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/PosixParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/OptionGroup.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/OptionValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/MissingArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/MissingOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/Util.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/BasicParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/AlreadySelectedException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/java/org/apache/commons/cli/PatternOptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/OptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/ValueTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/HelpFormatterExamples.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/OptionGroupTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/LongOptionWithShort.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/BuildTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/PatternOptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/GnuParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/ArgumentIsOptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/OptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/TestHelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/ParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/ValuesTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/ParseRequiredTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/ApplicationTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/OptionsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/UtilTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/BugsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/bug/BugCLI71Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/bug/BugCLI18Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/bug/BugCLI51Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/bug/BugCLI133Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli/bug/BugCLI13Test.java
# Found 45 files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/CLI2ConverterTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/CLI2Converter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/CommandLineParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/UnrecognizedOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/OptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/ParseException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/Options.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/TypeHandler.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/GnuParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/Parser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/PosixParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/OptionGroup.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/OptionValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/MissingArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/MissingOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/Util.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/BasicParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/AlreadySelectedException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/java/org/apache/commons/cli/PatternOptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/OptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/ValueTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/HelpFormatterExamples.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/OptionGroupTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/LongOptionWithShort.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/BuildTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/PatternOptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/GnuParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/ArgumentIsOptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/OptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/TestHelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/ParseTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/ValuesTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/ParseRequiredTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/ApplicationTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/OptionsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/UtilTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/BugsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/bug/BugCLI71Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/bug/BugCLI18Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/bug/BugCLI51Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/bug/BugCLI133Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed/src/test/org/apache/commons/cli/bug/BugCLI13Test.java
# Files unique to /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy:
# Files unique to /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_5_fixed:
# Files differing in content:
#   src/java/org/apache/commons/cli/Util.java
# Processing bug: 7
# Comparing files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy and /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_7_fixed
# Found 96 files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/WriteableCommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/HelpLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/Argument.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/Parent.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/DisplaySetting.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/OptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/Group.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/validation/UrlValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/validation/FileValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/validation/EnumValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/validation/DateValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/validation/ClassValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/validation/NumberValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/validation/InvalidArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/validation/Validator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/builder/PatternBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/builder/ArgumentBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/builder/CommandBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/builder/DefaultOptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/builder/SwitchBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/builder/GroupBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/util/Comparators.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/util/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/option/GroupImpl.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/option/Switch.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/option/OptionImpl.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/java/org/apache/commons/cli2/option/ParentImpl.java
# ...
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/ValueTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/OptionGroupTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/ParserTestCase.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/PatternOptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/GnuParserTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/HelpFormatterTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/ArgumentIsOptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/OptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/PosixParserTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/DefaultParserTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/ValuesTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/ApplicationTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/OptionsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/UtilTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugCLI148Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugCLI71Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugCLI162Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugCLI266Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugCLI252Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugCLI18Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugCLI133Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugCLI13Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli/bug/BugsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/CommandLineParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/UnrecognizedOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/OptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/ParseException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/package-info.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/Options.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/TypeHandler.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/GnuParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/Parser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/PosixParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/AmbiguousOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/OptionGroup.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/OptionValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/MissingArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/DefaultParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/MissingOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/Util.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/BasicParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/AlreadySelectedException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/main/java/org/apache/commons/cli/PatternOptionBuilder.java
# Found 49 files in /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/OptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/BasicParserTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/CommandLineTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/ValueTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/OptionGroupTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/ParserTestCase.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/PatternOptionBuilderTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/GnuParserTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/HelpFormatterTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/ArgumentIsOptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/OptionTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/PosixParserTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/DefaultParserTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/ValuesTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/ApplicationTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/OptionsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/UtilTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugCLI148Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugCLI71Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugCLI162Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugCLI266Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugCLI252Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugCLI18Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugCLI133Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugCLI13Test.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/test/java/org/apache/commons/cli/bug/BugsTest.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/CommandLineParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/UnrecognizedOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/OptionBuilder.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/ParseException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/package-info.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/Options.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/TypeHandler.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/GnuParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/Option.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/Parser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/HelpFormatter.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/CommandLine.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/PosixParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/AmbiguousOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/OptionGroup.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/OptionValidator.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/MissingArgumentException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/DefaultParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/MissingOptionException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/Util.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/BasicParser.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/AlreadySelectedException.java
#   /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed/src/main/java/org/apache/commons/cli/PatternOptionBuilder.java
# Files unique to /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy:
# Files unique to /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_FIXED/Cli/Cli_36_fixed:
# Files differing in content:
#   src/main/java/org/apache/commons/cli/OptionGroup.java
#   src/main/java/org/apache/commons/cli/Options.java

# %%
SOURCE_PATH = Path('/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli')

# list folders in SOURCE_PATH
full_paths = [f.path for f in os.scandir(SOURCE_PATH) if f.is_dir()]
folder_test_case_map = {}
for folder_path in full_paths:
    # find test cases folder
    # iterate over folders in folder_path, find folder that contains file ending with Test.java

    test_case_folder = None
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith("Test.java"):
                # if current folder contains test folder in its path, then it is the test folder
                if "test" in root:
                    test_case_folder = root
                    break
        if test_case_folder:
            break

    print(f"Test case folder: {test_case_folder}")
    if test_case_folder:
        bug_id = folder_path.split("_")[-2]
        # take relative path to folder_path
        test_case_folder = os.path.relpath(test_case_folder, SOURCE_PATH)
        folder_test_case_map[bug_id] = test_case_folder
# Out:
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_36_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_18_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_30_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_23_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_7_buggy/src/test/org/apache/commons/cli2
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_27_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_22_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_17_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_4_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_10_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_2_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_3_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_25_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_35_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_37_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_33_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_39_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_38_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_40_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_32_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_19_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_14_buggy/src/test/org/apache/commons/cli2
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_9_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_34_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_24_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_28_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_21_buggy/src/test/org/apache/commons/cli2
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_11_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_13_buggy/src/test/org/apache/commons/cli2
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_15_buggy/src/test/org/apache/commons/cli2
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_16_buggy/src/test/org/apache/commons/cli2
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_8_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_5_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_1_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_12_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_31_buggy/src/test/java/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_29_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_20_buggy/src/test/org/apache/commons/cli
# Test case folder: /mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/bug_fix_versions/OUTPUT_BUGGY/Cli/Cli_26_buggy/src/test/org/apache/commons/cli

# %%
generated_test_cases_folder = '/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/generated_tests'
# list all files in generated_test_cases_folder
files = glob(f'{generated_test_cases_folder}/**/*.java', recursive=True)
for generated_test_case in files:
    bug_id = generated_test_case.split("_")[-1].split(".")[0]
# Out:
# Bug ID: 12
# Bug ID: 17
# Bug ID: 40
# Bug ID: 33
# Bug ID: 36
# Bug ID: 26
# Bug ID: 39
# Bug ID: 30
# Bug ID: 14
# Bug ID: 20
# Bug ID: 19
# Bug ID: 18
# Bug ID: 11
# Bug ID: 13
# Bug ID: 25
# Bug ID: 5
# Bug ID: 29
# Bug ID: 4
# Bug ID: 10
# Bug ID: 23
# Bug ID: 7
# Bug ID: 35
# Bug ID: 22
# Bug ID: 38
# Bug ID: 9
# Bug ID: 8
# Bug ID: 27
# Bug ID: 16
# Bug ID: 31
# Bug ID: 28
# Bug ID: 21
# Bug ID: 37
# Bug ID: 15
# Bug ID: 34
# Bug ID: 3
# Bug ID: 32
# Bug ID: 24

# %%
# copy all test cases to dest paths in docker container
CONTAINER_ID = "c758b445f967"
# bug_id = 3
# dest_path = folder_test_case_map[str(bug_id)]
# cmd_command = [
#     "docker",
#     "cp",
#     f"/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/generated_tests/CustomTest_{bug_id}.java",
#     f"{CONTAINER_ID}:/usr/ressources/OUTPUT_BUGGY/Cli/{dest_path}/CustomTest.java"
# ]

generated_test_cases_folder = '/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/generated_tests'
# list all files in generated_test_cases_folder
files = glob(f'{generated_test_cases_folder}/**/*.java', recursive=True)
for generated_test_case in files:
    bug_id = generated_test_case.split("_")[-1].split(".")[0]
    dest_path = folder_test_case_map[str(bug_id)]
    cmd_command = [
        "docker",
        "cp",
        f"/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/generated_tests/CustomTest_{bug_id}.java",
        f"{CONTAINER_ID}:/usr/ressources/OUTPUT_BUGGY/Cli/{dest_path}/CustomTest.java"
    ]


    # run the command
    subprocess.run(cmd_command, check=True)

# %%
buggy_code_path = Path(bug_source_folder) / folder_comparison['differing_files'][0]
fixed_code_path = Path(bug_fixed_folder) / folder_comparison['differing_files'][0]

buggy_code = buggy_code_path.read_text()
fixed_code = fixed_code_path.read_text()

prompt = f'''There is a bug fix in the java code, Bug report is as follows:
{bug_report_parsed}
Buggy Code:
{buggy_code}
Fixed Code:
{fixed_code}
Generate test cases that covers the bug. Do not include any text or explanation, provide only the test cases.
'''

# %%
try:
    response = model.generate_content(prompt)
    print("Generated Unit Tests:\n")
    print(response.text.strip())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Generated Unit Tests:
#
# ```java
# import org.apache.commons.cli.Util;
# import org.junit.Test;
# import static org.junit.Assert.assertEquals;
# import static org.junit.Assert.assertNull;
#
# public class UtilTest {
#
#     @Test
#     public void testStripLeadingHyphensNull() {
#         assertNull(Util.stripLeadingHyphens(null));
#     }
#
#     @Test
#     public void testStripLeadingHyphensEmpty() {
#         assertEquals("", Util.stripLeadingHyphens(""));
#     }
#
#     @Test
#     public void testStripLeadingHyphensSingleHyphen() {
#         assertEquals("abc", Util.stripLeadingHyphens("-abc"));
#     }
#
#     @Test
#     public void testStripLeadingHyphensDoubleHyphen() {
#         assertEquals("abc", Util.stripLeadingHyphens("--abc"));
#     }
#
#     @Test
#     public void testStripLeadingHyphensNoHyphen() {
#         assertEquals("abc", Util.stripLeadingHyphens("abc"));
#     }
# }
# ```

# %%
generated_test_case = response.text.strip()
# write the generated test case to a file
test_case_file = Path('/mnt/seconddisk/master/courses/cs588/playgrounds.ipynb/generated_tests') / "generated_test_case.txt"
test_case_file.write_text(generated_test_case)
# Out:
# 828
